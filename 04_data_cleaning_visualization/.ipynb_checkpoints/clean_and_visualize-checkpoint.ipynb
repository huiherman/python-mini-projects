# %% [markdown]
# # 🧹 Data Cleaning & Visualization
# This notebook cleans data and creates visualizations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('sample_data.csv')
df.isnull().sum()
# Out:
# Name          0
# Age           0
# Department    0
# dtype: int64

# %%
# Drop missing values
df = df.dropna()
df.head()
# Out:
#       Name  Age Department
# 0    Alice   25         HR
# 1      Bob   32         IT
# 2  Charlie   45    Finance
# 3    David   28  Marketing
# 4      Eva   35         IT

# %%
# Visualize Age distribution
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()
